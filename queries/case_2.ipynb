# %%
# %pip install seaborn
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
# %inline 

path = '../portfolio.db'
conn = sqlite3.connect(path)

cur = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 import sqlite3
# ----> 3 import seaborn as sns
#       4 import matplotlib as plt
#       5 get_ipython().run_line_magic('inline', '')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# %pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-12.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 233.8 kB/s  0:00:11 eta 0:00:02
# ...

# %% [markdown]
# ### Extract from the file database

# %%
sales_df = pd.read_sql("select * from Superstore", conn)
sales_df.head(10)
# Out:
#    RowID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 1      2  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class   DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 5      6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 6      7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 7      8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 8      9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
# 9     10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class   BH-11710
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# ...

# %% [markdown]
# ### Transform

# %%
print(sales_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RowID         9994 non-null   int64
#  1   OrderID       9994 non-null   str
#  2   OrderDate     9994 non-null   datetime64[us]
#  3   ShipDate      9994 non-null   datetime64[us]
#  4   ShipMode      9994 non-null   str
#  5   CustomerID    9994 non-null   str
#  6   CustomerName  9994 non-null   str
#  7   Segment       9994 non-null   str
#  8   Country       9994 non-null   str
#  9   City          9994 non-null   str
#  10  State         9994 non-null   str
#  11  PostalCode    9994 non-null   int64
#  12  Region        9994 non-null   str
#  13  ProductID     9994 non-null   str
#  14  Category      9994 non-null   str
#  15  SubCategory   9994 non-null   str
#  16  ProductName   9994 non-null   str
#  17  Sales         9994 non-null   float64
#  18  Quantity      9994 non-null   int64
# ...

# %%
sales_df['OrderDate'] = pd.to_datetime(sales_df['OrderDate'], format='%m/%d/%Y')
print(sales_df.head(10))
# Out:
#    RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 1      2  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2      3  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3      4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4      5  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 5      6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 6      7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 7      8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 8      9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 9     10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# ...

# %%
sales_df['ShipDate'] = pd.to_datetime(sales_df['ShipDate'], format='%m/%d/%Y')
print(sales_df.head(10))
# Out:
#    RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 1      2  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2      3  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3      4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4      5  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 5      6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 6      7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 7      8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 8      9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# 9     10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# ...

# %%
sales_df.head()
# Out:
#    RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 1      2  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2      3  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3      4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4      5  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
# ...

# %%
sales_df['Sales'] = sales_df['Sales'].round(2)
sales_df['Profit'] = sales_df['Profit'].round(2)
print(sales_df.head())
# Out:
#    RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 1      2  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2      3  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3      4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4      5  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
# ...

# %%
sales_df.describe(exclude=['str'])
# Out:
#              RowID                   OrderDate                    ShipDate  \
# count  9994.000000                        9994                        9994
# mean   4997.500000  2016-04-30 00:07:12.259355  2016-05-03 23:06:58.571142
# min       1.000000         2014-01-03 00:00:00         2014-01-07 00:00:00
# 25%    2499.250000         2015-05-23 00:00:00         2015-05-27 00:00:00
# 50%    4997.500000         2016-06-26 00:00:00         2016-06-29 00:00:00
# 75%    7495.750000         2017-05-14 00:00:00         2017-05-18 00:00:00
# max    9994.000000         2017-12-30 00:00:00         2018-01-05 00:00:00
# std    2885.163629                         NaN                         NaN
#
#          PostalCode         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.857980     3.789574     0.156203    28.656848
# min     1040.000000      0.440000     1.000000     0.000000 -6599.980000
# ...

# %%
# check for date inconsistency
print("checking for date inconsistencies...")
inconsistency = sales_df[sales_df['OrderDate']>sales_df['ShipDate']][['OrderID','OrderDate','ShipDate']]

if inconsistency.isnull:
    print("All order dates are consistent (OrderDate < ShipDate)")
else:
    print("Date consistency is detected:")
    print(inconsistency)
# Out:
# checking for date inconsistencies...
# All order dates are consistent (OrderDate < ShipDate)

# %%
sales_df['Sales'].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sales_df['Sales'].plot()
#
# File ~/Downloads/sql_projects/.venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~/Downloads/sql_projects/.venv/lib/python3.11/site-packages/pandas/plotting/_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
# ...
